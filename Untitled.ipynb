# %%
print("hello World")
# Out:
# hello World

# %%
import sys
import os
import socket
import time


HOST = "127.0.0.1"  # Replace
PORT = 13000 #Default port
s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
s.connect((HOST, PORT))
message  = "<Message>\r\n"
message += "   <QuickShimRequest/>\r\n"
message += "</Message>\r\n"

s.send(message.encode())
print('\r\nMessage received:')
s.settimeout(10.0)
try:
    while True:
        time.sleep(0.2)
        chunk = s.recv(8192)
        if chunk:
            print(chunk.decode())
except socket.error as msg:
    s.settimeout(None)
    # will only get here if a timeout occurs
    print('\r\nClose connection')
    s.close()
# Out:
# Connect to 127.0.0.1:13000
#
# Send message:
# <Message>
#    <QuickShimRequest/>
# </Message>
#
#
# Message received:
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:37:37">
#     <Progress protocol="SHIM" percentage="1" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:37:40">
#     <Progress protocol="SHIM" percentage="2" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:37:43">
#     <Progress protocol="SHIM" percentage="3" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:37:46">
#     <Progress protocol="SHIM" percentage="4" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:37:49">
#     <Progress protocol="SHIM" percentage="5" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:37:52">
#     <Progress protocol="SHIM" percentage="6" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:37:55">
#     <Progress protocol="SHIM" percentage="7" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:37:58">
#     <Progress protocol="SHIM" percentage="8" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:38:01">
#     <Progress protocol="SHIM" percentage="9" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:38:04">
#     <Progress protocol="SHIM" percentage="10" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:38:07">
#     <Progress protocol="SHIM" percentage="11" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:38:11">
#     <Progress protocol="SHIM" percentage="12" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:38:14">
#     <Progress protocol="SHIM" percentage="13" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:38:17">
#     <Progress protocol="SHIM" percentage="14" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:38:20">
#     <Progress protocol="SHIM" percentage="15" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:38:23">
#     <Progress protocol="SHIM" percentage="16" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:38:26">
#     <Progress protocol="SHIM" percentage="17" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:38:29">
#     <Progress protocol="SHIM" percentage="18" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:38:32">
#     <Progress protocol="SHIM" percentage="19" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:38:35">
#     <Progress protocol="SHIM" percentage="20" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:38:38">
#     <Progress protocol="SHIM" percentage="21" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:38:42">
#     <Progress protocol="SHIM" percentage="22" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:38:45">
#     <Progress protocol="SHIM" percentage="23" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:38:48">
#     <Progress protocol="SHIM" percentage="24" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:38:51">
#     <Progress protocol="SHIM" percentage="25" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:38:54">
#     <Progress protocol="SHIM" percentage="26" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:38:57">
#     <Progress protocol="SHIM" percentage="27" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:39:00">
#     <Progress protocol="SHIM" percentage="28" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:39:03">
#     <Progress protocol="SHIM" percentage="29" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:39:06">
#     <Progress protocol="SHIM" percentage="30" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:39:09">
#     <Progress protocol="SHIM" percentage="31" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:39:13">
#     <Progress protocol="SHIM" percentage="32" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:39:16">
#     <Progress protocol="SHIM" percentage="33" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:39:19">
#     <Progress protocol="SHIM" percentage="34" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:39:22">
#     <Progress protocol="SHIM" percentage="35" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:39:25">
#     <Progress protocol="SHIM" percentage="36" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:39:28">
#     <Progress protocol="SHIM" percentage="37" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:39:31">
#     <Progress protocol="SHIM" percentage="38" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:39:34">
#     <Progress protocol="SHIM" percentage="39" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:39:37">
#     <Progress protocol="SHIM" percentage="40" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:39:40">
#     <Progress protocol="SHIM" percentage="41" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:39:44">
#     <Progress protocol="SHIM" percentage="42" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:39:47">
#     <Progress protocol="SHIM" percentage="43" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:39:50">
#     <Progress protocol="SHIM" percentage="44" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:39:53">
#     <Progress protocol="SHIM" percentage="45" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:39:56">
#     <Progress protocol="SHIM" percentage="46" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:39:59">
#     <Progress protocol="SHIM" percentage="47" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:40:02">
#     <Progress protocol="SHIM" percentage="48" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="12:40:05">
#     <Progress protocol="SHIM" percentage="49" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <QuickShimResponse error="">
#     <OperatingTemperature>true</OperatingTemperature>
#     <StableTemperatures>true</StableTemperatures>
#     <StableLock>true</StableLock>
#     <LineWidth>0.294885963</LineWidth>
#     <BaseWidth>5.47942</BaseWidth>
#     <SystemIsReady>true</SystemIsReady>
#   </QuickShimResponse>
# </Message>
#
# Close connection

# %%
import sys
import os
import socket
import time

#  send quick scan request

HOST = "127.0.0.1"  # Replace
PORT = 13000 #Default port
print('Connect to ' + HOST + ':' + str(PORT))
s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
s.connect((HOST, PORT))
message  = "<Message>\r\n"
message += "   <Start protocol='1D PROTON'>\r\n"
message += "     <Option name='Scan' value='QuickScan' />\r\n"
message += "   </Start>\r\n"
message += "</Message>\r\n"
print('\r\nSend message:')
print(message)
s.send(message.encode())
print('\r\nMessage received:')
s.settimeout(10.0)
try:
    while True:
        time.sleep(0.2)
        chunk = s.recv(8192)
        if chunk:
            print(chunk.decode())
except socket.error as msg:
    s.settimeout(None)
    # will only get here if a timeout occurs
    print('\r\nClose connection')
    s.close()
# Out:
# Connect to 127.0.0.1:13000
#
# Send message:
# <Message>
#    <Start protocol='1D PROTON'>
#      <Option name='Scan' value='QuickScan' />
#    </Start>
# </Message>
#
#
# Message received:
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="10:31:20">
#     <Progress protocol="1D PROTON" percentage="10" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="10:31:21">
#     <Progress protocol="1D PROTON" percentage="20" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="10:31:22">
#     <Progress protocol="1D PROTON" percentage="30" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="10:31:23">
#     <Progress protocol="1D PROTON" percentage="40" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="10:31:24">
#     <Progress protocol="1D PROTON" percentage="50" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="10:31:25">
#     <Progress protocol="1D PROTON" percentage="60" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="10:31:26">
#     <Progress protocol="1D PROTON" percentage="70" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="10:31:27">
#     <Progress protocol="1D PROTON" percentage="80" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="10:31:29">
#     <Progress protocol="1D PROTON" percentage="90" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="10:31:29">
#     <Progress protocol="1D PROTON" percentage="100" />
#   </StatusNotification>
# </Message>
#
# Close connection

# %%
# Sample shim test
import sys
import os
import socket
import time

#  send quick scan request

HOST = "127.0.0.1"  # Replace
PORT = 13000 #Default port
print('Connect to ' + HOST + ':' + str(PORT))
s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
s.connect((HOST, PORT))
message  = "<Message>\r\n"
message += "   <Start protocol='SHIM 1H SAMPLE'>\r\n"
message += "     <Option name='SampleReference' value='4.74' />\r\n"
message += "     <Option name='Shim' value='QuickShim1' />\r\n"
message += "   </Start>\r\n"
message += "</Message>\r\n"
print('\r\nSend message:')
print(message)
s.send(message.encode())
print('\r\nMessage received:')
s.settimeout(10.0)
try:
    while True:
        time.sleep(0.2)
        chunk = s.recv(8192)
        if chunk:
            print(chunk.decode())
except socket.error as msg:
    s.settimeout(None)
    # will only get here if a timeout occurs
    print('\r\nClose connection')
    s.close()
# Out:
# Connect to 127.0.0.1:13000
#
# Send message:
# <Message>
#    <Start protocol='SHIM 1H SAMPLE'>
#      <Option name='SampleReference' value='4.74' />
#      <Option name='Shim' value='QuickShim1' />
#    </Start>
# </Message>
#
#
# Message received:
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:21:20">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="1" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:21:21">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="2" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:21:23">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="3" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:21:24">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="4" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:21:25">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="5" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:21:26">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="6" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:21:27">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="7" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:21:28">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="8" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:21:30">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="9" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:21:31">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="10" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:21:32">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="11" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:21:33">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="12" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:21:34">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="13" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:21:36">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="14" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:21:37">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="15" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:21:38">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="16" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:21:41">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="17" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:21:41">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="18" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:21:42">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="19" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:21:43">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="20" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:21:44">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="21" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:21:45">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="22" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:21:46">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="23" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:21:48">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="24" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:21:49">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="25" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:21:50">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="26" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:21:51">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="27" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:21:52">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="28" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:21:54">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="29" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:21:55">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="30" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:21:56">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="31" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:21:57">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="32" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:21:58">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="33" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:00">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="34" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:01">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="35" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:02">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="36" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:03">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="37" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:04">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="38" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:06">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="39" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:07">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="40" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:08">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="41" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:09">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="42" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:10">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="43" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:12">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="44" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:13">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="45" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:14">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="46" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:15">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="47" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:16">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="48" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:18">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="49" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:19">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="50" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:20">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="51" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:21">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="52" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:22">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="53" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:24">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="54" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:25">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="55" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:26">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="56" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:27">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="57" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:28">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="58" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:30">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="59" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:31">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="60" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:32">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="61" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:33">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="62" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:34">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="63" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:36">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="64" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:37">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="65" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:38">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="66" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:39">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="67" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:40">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="68" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:42">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="69" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:43">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="70" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:44">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="71" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:45">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="72" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:46">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="73" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:48">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="74" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:49">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="75" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:50">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="76" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:51">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="77" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:52">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="78" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:54">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="79" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:55">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="80" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:56">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="81" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:57">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="82" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:22:58">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="83" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:23:00">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="84" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:23:01">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="85" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:23:02">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="86" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:23:03">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="87" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:23:04">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="88" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:23:06">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="89" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:23:07">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="90" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:23:08">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="91" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:23:09">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="92" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:23:10">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="93" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:23:12">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="94" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:23:13">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="95" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:23:14">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="96" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:23:15">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="97" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:23:16">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="98" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:23:18">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="99" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:23:19">
#     <Progress protocol="SHIM 1H SAMPLE" percentage="100" />
#   </StatusNotification>
# </Message>
#
# Close connection

# %%
# 1 H  Protocol
# 13 C Protocol --> no license
# 19 F Protocol

import sys
import os
import socket
import time

#  send quick scan request

HOST = "127.0.0.1"  # Replace
PORT = 13000 #Default port
print('Connect to ' + HOST + ':' + str(PORT))
s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
s.connect((HOST, PORT))
message  = "<Message>\r\n"
message += "   <Start protocol='1D PROTON'>\r\n"
message += "     <Option name='Scan' value='QuickScan' />\r\n"
message += "   </Start>\r\n"
message += "</Message>\r\n"
print('\r\nSend message:')
print(message)
s.send(message.encode())
print('\r\nMessage received:')
s.settimeout(10.0)
try:
    while True:
        time.sleep(0.2)
        chunk = s.recv(8192)
        if chunk:
            print(chunk.decode())
except socket.error as msg:
    s.settimeout(None)
    # will only get here if a timeout occurs
    print('\r\nClose connection')
    s.close()
# Out:
# Connect to 127.0.0.1:13000
#
# Send message:
# <Message>
#    <Start protocol='1D PROTON+'>
#      <Option name='Scan' value='QuickScan' />
#    </Start>
# </Message>
#
#
# Message received:
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="10:46:27">
#     <Error protocol="NO PROTOCOL SELECTED" error="Could not find protocol '1D PROTON+'" />
#   </StatusNotification>
# </Message>
#
# Close connection

# %%
# 1 H  Protocol
# 13 C Protocol --> no license
# 19 F Protocol

import sys
import os
import socket
import time

#  send quick scan request

HOST = "127.0.0.1"  # Replace
PORT = 13000 #Default port
print('Connect to ' + HOST + ':' + str(PORT))
s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
s.connect((HOST, PORT))
message  = "<Message>\r\n"
message += "   <Start protocol='1D PROTON'>\r\n"
message += "     <Option name='Scan' value='QuickScan' />\r\n"
message += "     <Processing>\r\n"
message += "       <Press Name='MNOVA'  />\r\n"
message += "     </Processing>\r\n"
message += "   </Start>\r\n"
message += "</Message>\r\n"
print('\r\nSend message:')
print(message)
s.send(message.encode())
print('\r\nMessage received:')
s.settimeout(10.0)
try:
    while True:
        time.sleep(0.2)
        chunk = s.recv(8192)
        if chunk:
            print(chunk.decode())
except socket.error as msg:
    s.settimeout(None)
    # will only get here if a timeout occurs
    print('\r\nClose connection')
    s.close()
# Out:
# Connect to 127.0.0.1:13000
#
# Send message:
# <Message>
#    <Start protocol='1D PROTON'>
#      <Option name='Scan' value='QuickScan' />
#      <Processing>
#        <Press Name='MNOVA'  />
#      </Processing>
#    </Start>
# </Message>
#
#
# Message received:
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="10:45:52">
#     <Progress protocol="1D PROTON" percentage="10" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="10:45:53">
#     <Progress protocol="1D PROTON" percentage="20" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="10:45:54">
#     <Progress protocol="1D PROTON" percentage="30" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="10:45:55">
#     <Progress protocol="1D PROTON" percentage="40" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="10:45:56">
#     <Progress protocol="1D PROTON" percentage="50" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="10:45:57">
#     <Progress protocol="1D PROTON" percentage="60" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="10:45:58">
#     <Progress protocol="1D PROTON" percentage="70" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="10:45:59">
#     <Progress protocol="1D PROTON" percentage="80" />
#   </StatusNotification>
# </Message>
#
# Close connection

# %%
# Test for scripting
# 1 H  Protocol
# 13 C Protocol --> no license
# 19 F Protocol

import sys
import os
import socket
import time

#  send quick scan request

HOST = "127.0.0.1"  # Replace
PORT = 13000 #Default port
print('Connect to ' + HOST + ':' + str(PORT))
s = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
s.connect((HOST, PORT))
message  = "<Message>\r\n"
message +="<Start protocol='1D EXTENDED+'>\r\n"
message +="<Option name='Number' value='4' />\r\n"
message +="<Option name='AquisitionTime' value='3.2' />\r\n"
message +="<Option name='RepetitionTime' value='30' />\r\n"
message +="<Option name='PulseAngle' value='90' />\r\n"
message += "   </Start>\r\n"
message += "</Message>\r\n"
print('\r\nSend message:')
print(message)
s.send(message.encode())
print('\r\nMessage received:')
s.settimeout(10.0)
try:
    while True:
        time.sleep(0.2)
        chunk = s.recv(8192)
        if chunk:
            print(chunk.decode())
except socket.error as msg:
    s.settimeout(None)
    # will only get here if a timeout occurs
    print('\r\nClose connection')
    s.close()
# Out:
# Connect to 127.0.0.1:13000
#
# Send message:
# <Message>
# <Start protocol='1D EXTENDED+'>
# <Option name='Number' value='4' />
# <Option name='AquisitionTime' value='3.2' />
# <Option name='RepetitionTime' value='30' />
# <Option name='PulseAngle' value='90' />
#    </Start>
# </Message>
#
#
# Message received:
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:15:40">
#     <Error protocol="1D EXTENDED+" error="Problem parsing option 'AquisitionTime' = '3.2' : There is no parameter named : AquisitionTime" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:15:42">
#     <Progress protocol="1D EXTENDED+" percentage="1" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:15:43">
#     <Progress protocol="1D EXTENDED+" percentage="2" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:15:45">
#     <Progress protocol="1D EXTENDED+" percentage="3" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:15:46">
#     <Progress protocol="1D EXTENDED+" percentage="4" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:15:47">
#     <Progress protocol="1D EXTENDED+" percentage="5" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:15:48">
#     <Progress protocol="1D EXTENDED+" percentage="6" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:15:50">
#     <Progress protocol="1D EXTENDED+" percentage="7" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:15:51">
#     <Progress protocol="1D EXTENDED+" percentage="8" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:15:52">
#     <Progress protocol="1D EXTENDED+" percentage="9" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:15:53">
#     <Progress protocol="1D EXTENDED+" percentage="10" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:15:54">
#     <Progress protocol="1D EXTENDED+" percentage="11" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:15:55">
#     <Progress protocol="1D EXTENDED+" percentage="12" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:15:57">
#     <Progress protocol="1D EXTENDED+" percentage="13" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:15:58">
#     <Progress protocol="1D EXTENDED+" percentage="14" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:15:59">
#     <Progress protocol="1D EXTENDED+" percentage="15" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:00">
#     <Progress protocol="1D EXTENDED+" percentage="16" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:01">
#     <Progress protocol="1D EXTENDED+" percentage="17" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:03">
#     <Progress protocol="1D EXTENDED+" percentage="18" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:04">
#     <Progress protocol="1D EXTENDED+" percentage="19" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:05">
#     <Progress protocol="1D EXTENDED+" percentage="20" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:06">
#     <Progress protocol="1D EXTENDED+" percentage="21" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:07">
#     <Progress protocol="1D EXTENDED+" percentage="22" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:09">
#     <Progress protocol="1D EXTENDED+" percentage="23" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:10">
#     <Progress protocol="1D EXTENDED+" percentage="24" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:11">
#     <Progress protocol="1D EXTENDED+" percentage="25" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:12">
#     <Progress protocol="1D EXTENDED+" percentage="26" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:13">
#     <Progress protocol="1D EXTENDED+" percentage="27" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:15">
#     <Progress protocol="1D EXTENDED+" percentage="28" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:16">
#     <Progress protocol="1D EXTENDED+" percentage="29" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:17">
#     <Progress protocol="1D EXTENDED+" percentage="30" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:18">
#     <Progress protocol="1D EXTENDED+" percentage="31" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:19">
#     <Progress protocol="1D EXTENDED+" percentage="32" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:21">
#     <Progress protocol="1D EXTENDED+" percentage="33" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:22">
#     <Progress protocol="1D EXTENDED+" percentage="34" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:23">
#     <Progress protocol="1D EXTENDED+" percentage="35" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:24">
#     <Progress protocol="1D EXTENDED+" percentage="36" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:25">
#     <Progress protocol="1D EXTENDED+" percentage="37" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:27">
#     <Progress protocol="1D EXTENDED+" percentage="38" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:28">
#     <Progress protocol="1D EXTENDED+" percentage="39" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:29">
#     <Progress protocol="1D EXTENDED+" percentage="40" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:30">
#     <Progress protocol="1D EXTENDED+" percentage="41" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:31">
#     <Progress protocol="1D EXTENDED+" percentage="42" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:33">
#     <Progress protocol="1D EXTENDED+" percentage="43" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:34">
#     <Progress protocol="1D EXTENDED+" percentage="44" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:35">
#     <Progress protocol="1D EXTENDED+" percentage="45" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:36">
#     <Progress protocol="1D EXTENDED+" percentage="46" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:37">
#     <Progress protocol="1D EXTENDED+" percentage="47" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:39">
#     <Progress protocol="1D EXTENDED+" percentage="48" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:40">
#     <Progress protocol="1D EXTENDED+" percentage="49" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:41">
#     <Progress protocol="1D EXTENDED+" percentage="50" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:42">
#     <Progress protocol="1D EXTENDED+" percentage="51" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:43">
#     <Progress protocol="1D EXTENDED+" percentage="52" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:45">
#     <Progress protocol="1D EXTENDED+" percentage="53" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:46">
#     <Progress protocol="1D EXTENDED+" percentage="54" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:47">
#     <Progress protocol="1D EXTENDED+" percentage="55" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:48">
#     <Progress protocol="1D EXTENDED+" percentage="56" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:49">
#     <Progress protocol="1D EXTENDED+" percentage="57" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:51">
#     <Progress protocol="1D EXTENDED+" percentage="58" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:52">
#     <Progress protocol="1D EXTENDED+" percentage="59" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:53">
#     <Progress protocol="1D EXTENDED+" percentage="60" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:54">
#     <Progress protocol="1D EXTENDED+" percentage="61" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:55">
#     <Progress protocol="1D EXTENDED+" percentage="62" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:57">
#     <Progress protocol="1D EXTENDED+" percentage="63" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:58">
#     <Progress protocol="1D EXTENDED+" percentage="64" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:16:59">
#     <Progress protocol="1D EXTENDED+" percentage="65" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:00">
#     <Progress protocol="1D EXTENDED+" percentage="66" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:01">
#     <Progress protocol="1D EXTENDED+" percentage="67" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:03">
#     <Progress protocol="1D EXTENDED+" percentage="68" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:04">
#     <Progress protocol="1D EXTENDED+" percentage="69" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:05">
#     <Progress protocol="1D EXTENDED+" percentage="70" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:06">
#     <Progress protocol="1D EXTENDED+" percentage="71" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:07">
#     <Progress protocol="1D EXTENDED+" percentage="72" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:09">
#     <Progress protocol="1D EXTENDED+" percentage="73" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:10">
#     <Progress protocol="1D EXTENDED+" percentage="74" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:11">
#     <Progress protocol="1D EXTENDED+" percentage="75" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:12">
#     <Progress protocol="1D EXTENDED+" percentage="76" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:13">
#     <Progress protocol="1D EXTENDED+" percentage="77" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:15">
#     <Progress protocol="1D EXTENDED+" percentage="78" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:16">
#     <Progress protocol="1D EXTENDED+" percentage="79" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:17">
#     <Progress protocol="1D EXTENDED+" percentage="80" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:18">
#     <Progress protocol="1D EXTENDED+" percentage="81" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:19">
#     <Progress protocol="1D EXTENDED+" percentage="82" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:21">
#     <Progress protocol="1D EXTENDED+" percentage="83" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:22">
#     <Progress protocol="1D EXTENDED+" percentage="84" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:23">
#     <Progress protocol="1D EXTENDED+" percentage="85" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:24">
#     <Progress protocol="1D EXTENDED+" percentage="86" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:25">
#     <Progress protocol="1D EXTENDED+" percentage="87" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:27">
#     <Progress protocol="1D EXTENDED+" percentage="88" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:28">
#     <Progress protocol="1D EXTENDED+" percentage="89" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:29">
#     <Progress protocol="1D EXTENDED+" percentage="90" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:30">
#     <Progress protocol="1D EXTENDED+" percentage="91" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:31">
#     <Progress protocol="1D EXTENDED+" percentage="92" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:33">
#     <Progress protocol="1D EXTENDED+" percentage="93" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:34">
#     <Progress protocol="1D EXTENDED+" percentage="94" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:35">
#     <Progress protocol="1D EXTENDED+" percentage="95" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:36">
#     <Progress protocol="1D EXTENDED+" percentage="96" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:37">
#     <Progress protocol="1D EXTENDED+" percentage="97" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:39">
#     <Progress protocol="1D EXTENDED+" percentage="98" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:40">
#     <Progress protocol="1D EXTENDED+" percentage="99" />
#   </StatusNotification>
# </Message>
# <?xml version="1.0" encoding="utf-8"?>
# <Message>
#   <StatusNotification timestamp="11:17:41">
#     <Progress protocol="1D EXTENDED+" percentage="100" />
#   </StatusNotification>
# </Message>
#
# Close connection
